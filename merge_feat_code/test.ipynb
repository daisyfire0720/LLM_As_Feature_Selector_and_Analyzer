# %%
import joblib
param_path = '../output_full/' + 'corner_step_x_lgb_param.joblib'
params = joblib.load(param_path)
print(list(params.keys()))
# Out:
# ['bagging_fraction', 'bagging_freq', 'feature_fraction', 'learning_rate', 'max_bin', 'max_depth', 'min_child_samples', 'min_child_weight', 'min_data_in_bin', 'num_leaves', 'reg_alpha', 'reg_lambda', 'n_estimators', 'task', 'boosting_type', 'objective', 'metric', 'device']
